# %% [markdown]
# ## Heart Disease Predictor

# %% [markdown]
# ### Importing Numpy and Pandas module

# %%
import numpy as np 
import pandas as pd

# %%
file = "./Heart_disease_statlog.csv"
attributes = ['age', 'sex', 'chest_pain', 'BP', 'cholesterol', 'fasting_bloodsugar', 'rest_ecg', 'max_heartrate', 'exercise_angina', 'oldpeak', 'slope', 'ca', 'thal', 'target']
df = pd.read_csv(file, header = 1, names = attributes)

# %%
df
# Out:
#      age  sex  chest_pain   BP  cholesterol  fasting_bloodsugar  rest_ecg  \
# 0     67    0           2  115          564                   0         2
# 1     57    1           1  124          261                   0         0
# 2     64    1           3  128          263                   0         0
# 3     74    0           1  120          269                   0         2
# 4     65    1           3  120          177                   0         0
# ..   ...  ...         ...  ...          ...                 ...       ...
# 264   52    1           2  172          199                   1         0
# 265   44    1           1  120          263                   0         0
# 266   56    0           1  140          294                   0         2
# 267   57    1           3  140          192                   0         0
# 268   67    1           3  160          286                   0         2
#
#      max_heartrate  exercise_angina  oldpeak  slope  ca  thal  target
# 0              160                0      1.6      1   0     3       0
# 1              141                0      0.3      0   0     3       1
# 2              105                1      0.2      1   1     3       0
# 3              121                1      0.2      0   1     1       0
# 4              140                0      0.4      0   0     3       0
# ..             ...              ...      ...    ...  ..   ...     ...
# 264            162                0      0.5      0   0     3       0
# 265            173                0      0.0      0   0     3       0
# 266            153                0      1.3      1   0     1       0
# 267            148                0      0.4      1   0     2       0
# 268            108                1      1.5      1   3     1       1
#
# [269 rows x 14 columns]

# %%
df.describe
# Out:
# <bound method NDFrame.describe of      age  sex  chest_pain   BP  cholesterol  fasting_bloodsugar  rest_ecg  \
# 0     67    0           2  115          564                   0         2
# 1     57    1           1  124          261                   0         0
# 2     64    1           3  128          263                   0         0
# 3     74    0           1  120          269                   0         2
# 4     65    1           3  120          177                   0         0
# ..   ...  ...         ...  ...          ...                 ...       ...
# 264   52    1           2  172          199                   1         0
# 265   44    1           1  120          263                   0         0
# 266   56    0           1  140          294                   0         2
# 267   57    1           3  140          192                   0         0
# 268   67    1           3  160          286                   0         2
#
#      max_heartrate  exercise_angina  oldpeak  slope  ca  thal  target
# 0              160                0      1.6      1   0     3       0
# 1              141                0      0.3      0   0     3       1
# 2              105                1      0.2      1   1     3       0
# 3              121                1      0.2      0   1     1       0
# 4              140                0      0.4      0   0     3       0
# ..             ...              ...      ...    ...  ..   ...     ...
# 264            162                0      0.5      0   0     3       0
# 265            173                0      0.0      0   0     3       0
# 266            153                0      1.3      1   0     1       0
# 267            148                0      0.4      1   0     2       0
# 268            108                1      1.5      1   3     1       1
#
# [269 rows x 14 columns]>

# %%
df.head()
# Out:
#    age  sex  chest_pain   BP  cholesterol  fasting_bloodsugar  rest_ecg  \
# 0   67    0           2  115          564                   0         2
# 1   57    1           1  124          261                   0         0
# 2   64    1           3  128          263                   0         0
# 3   74    0           1  120          269                   0         2
# 4   65    1           3  120          177                   0         0
#
#    max_heartrate  exercise_angina  oldpeak  slope  ca  thal  target
# 0            160                0      1.6      1   0     3       0
# 1            141                0      0.3      0   0     3       1
# 2            105                1      0.2      1   1     3       0
# 3            121                1      0.2      0   1     1       0
# 4            140                0      0.4      0   0     3       0

# %% [markdown]
# ### Data Visualization

# %% [markdown]
# #### Importing required modules

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Few features of the dataset are further classified based on their values. Let's claasify them for better plotting.

# %%
data = pd.read_csv(file, header = 1, names = attributes)

# %%
data['sex'][data['sex'] == 0] = 'Female'
data['sex'][data['sex'] == 1] = 'Male'

data['chest_pain'][data['chest_pain'] == 0] = 'typical angina'
data['chest_pain'][data['chest_pain'] == 1] = 'atypical angina'
data['chest_pain'][data['chest_pain'] == 2] = 'non-typical angina'
data['chest_pain'][data['chest_pain'] == 3] = 'asymptomatic'

data['rest_ecg'][data['rest_ecg'] == 0] = 'normal'
data['rest_ecg'][data['rest_ecg'] == 1] = 'abnormal in ST-T wave'
data['rest_ecg'][data['rest_ecg'] == 2] = 'left ventricular hypertrophy'

data['slope'][data['slope'] == 0] = 'up sloping'
data['slope'][data['slope'] == 1] = 'flat'
data['slope'][data['slope'] == 2] = 'down sloping'

data['thal'][data['thal'] == 0] = 'NULL'
data['thal'][data['thal'] == 1] = 'normal blood flow'
data['thal'][data['thal'] == 2] = 'fixed defect'
data['thal'][data['thal'] == 3] = 'reversible defect'
# Out:
# C:\Users\Kaushik\AppData\Local\Temp\ipykernel_15844\8922078.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['sex'][data['sex'] == 0] = 'Female'
# C:\Users\Kaushik\AppData\Local\Temp\ipykernel_15844\8922078.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['chest_pain'][data['chest_pain'] == 0] = 'typical angina'
# C:\Users\Kaushik\AppData\Local\Temp\ipykernel_15844\8922078.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['rest_ecg'][data['rest_ecg'] == 0] = 'normal'
# C:\Users\Kaushik\AppData\Local\Temp\ipykernel_15844\8922078.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['slope'][data['slope'] == 0] = 'up sloping'
# C:\Users\Kaushik\AppData\Local\Temp\ipykernel_15844\8922078.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['thal'][data['thal'] == 0] = 'NULL'
# C:\Users\Kaushik\AppData\Local\Temp\ipykernel_15844\8922078.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['thal'][data['thal'] == 1] = 'normal blood flow'

# %% [markdown]
# Checking the number of individuals with different features

# %%
data['sex'].value_counts()
# Out:
# Male      182
# Female     87
# Name: sex, dtype: int64

# %%
data['rest_ecg'].value_counts()
# Out:
# left ventricular hypertrophy    136
# normal                          131
# abnormal in ST-T wave             2
# Name: rest_ecg, dtype: int64

# %%
data['chest_pain'].value_counts()
# Out:
# asymptomatic          128
# non-typical angina     79
# atypical angina        42
# typical angina         20
# Name: chest_pain, dtype: int64

# %%
data['thal'].value_counts()
# Out:
# normal blood flow    151
# reversible defect    104
# fixed defect          14
# Name: thal, dtype: int64

# %%
# number of individuals with and without heart disease

df['target'].value_counts().plot.pie(autopct = "%1.0f%%", labels=["Normal", "Heart Disease"], startangle = 0, colors = sns.color_palette("crest"))
# Out:
# <AxesSubplot: ylabel='target'>

# %%
# scatter plot of BP and cholesterol for individual with and without heart disease

sns.scatterplot(x = 'BP', y = 'cholesterol', hue = 'target', data = data)
# Out:
# <AxesSubplot: xlabel='BP', ylabel='cholesterol'>

# %%
# scatter plot of BP and age for individuals with and withour heart disease

sns.scatterplot(x = 'BP', y = 'age', hue = 'target', data = data)
# Out:
# <AxesSubplot: xlabel='BP', ylabel='age'>

# %%
# scatter plot of cholesterol and age for individuals with and without heart disease

sns.scatterplot(x = 'cholesterol', y = 'age', hue = 'target', data = data)
# Out:
# <AxesSubplot: xlabel='cholesterol', ylabel='age'>

# %%
# relation between cholesterol level and sex of an individual

sns.histplot(data = data, x = 'cholesterol', kde = True, hue = 'sex')
# Out:
# <AxesSubplot: xlabel='cholesterol', ylabel='Count'>
